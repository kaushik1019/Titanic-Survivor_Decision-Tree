# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
train_df = pd.read_csv('../input/train.csv')

# %%
train_df.head()

# %%
gender_df = pd.read_csv('../input/gender_submission.csv')
gender_df.head()

# %%
train_df.shape

# %%
train_df.describe()

# %%
train_df.isna().sum()

# %%
train_df['Age'].fillna(value= train_df['Age'].mean(), inplace= True)

# %%
train_df.isna().sum()

# %%
train_df.info()

# %%
train_df= pd.get_dummies(data=train_df, columns=['Sex'])
train_df.head()

# %%
train_df.columns

# %%
train_df.info()

# %%
input_var = [col for col in train_df.columns if train_df[col].dtype != 'object']
input_var

# %%
output_var = 'Survived'
input_var.remove(output_var)

# %%
input_var

# %%
train_df['Embarked'].value_counts()

# %%
train_df['Embarked'].fillna('S', inplace= True)

# %%
train_df['Embarked'].value_counts()

# %%
train_df= pd.get_dummies(data=train_df, columns=['Embarked'])
train_df.head()

# %%
input_var = [col for col in train_df.columns if train_df[col].dtype != 'object']
input_var

# %%
input_var.remove('PassengerId')

# %%
input_var.remove('Survived')

# %%
output_var

# %%
input_var

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(train_df[input_var], train_df[output_var], test_size = 0.25)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt1 = DecisionTreeClassifier()

# %%
dt1.fit(X=x_train[input_var], y=y_train)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_pred=dt1.predict(x_train[input_var]), y_true=y_train))
print(accuracy_score(y_pred=dt1.predict(x_val[input_var]), y_true=y_val))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf1 = RandomForestClassifier(n_estimators=100)

# %%
rf1.fit(X=x_train[input_var], y=y_train)

# %%
print(accuracy_score(y_pred=rf1.predict(X=x_train[input_var]), y_true=y_train))
print(accuracy_score(y_pred=rf1.predict(X=x_val[input_var]), y_true=y_val))
